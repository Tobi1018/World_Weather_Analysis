# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests
 
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5525f451f3e4d4614602a50b54a7446c

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | norrtalje
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | souillac
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | saint-pierre
# Processing Record 11 of Set 1 | narsaq
# Processing Record 12 of Set 1 | san jose de guanipa
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | nanortalik
# Processing Record 15 of Set 1 | sept-iles
# Processing Record 16 of Set 1 | coahuayana
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | allada
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | bull savanna
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | lannion
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | muros
# Processing Record 41 of Set 1 | labuan
# Processing Record 42 of Set 1 | daru
# Processing Record 43 of Set 1 | huntsville
# Processing Record 44 of Set 1 | ambovombe
# Processing Record 45 of Set 1 | svetlogorsk
# Processing Record 46 of Set 1 | vinh
# Processing Record 47 of Set 1 | sekoma
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | sroda wielkopolska
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | providencia
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | arinos
# Processing Record 7 of Set 2 | oyem
# Processing Record 8 of Set 2 | pangody
# Processing Record 9 of Set 2 | maumere
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | gastonia
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | chilca
# Processing Record 16 of Set 2 | meulaboh
# Processing Record 17 of Set 2 | kiunga
# Processing Record 18 of Set 2 | matane
# Processing Record 19 of Set 2 | ixtapa
# Processing Record 20 of Set 2 | osa
# Processing Record 21 of Set 2 | cobija
# Processing Record 22 of Set 2 | lakes entrance
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | saint-prosper
# Processing Record 26 of Set 2 | avera
# Processing Record 27 of Set 2 | krasnoselkup
# Processing Record 28 of Set 2 | sassandra
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | provost
# Processing Record 32 of Set 2 | port hardy
# Processing Record 33 of Set 2 | odweyne
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 2 | henties bay
# Processing Record 37 of Set 2 | flinders
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | slave lake
# Processing Record 40 of Set 2 | pomabamba
# Processing Record 41 of Set 2 | yakeshi
# Processing Record 42 of Set 2 | vaitape
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | carutapera
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | sao joao da barra
# Processing Record 50 of Set 2 | baghmara
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | senanga
# Processing Record 3 of Set 3 | valparaiso
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | kabalo
# Processing Record 7 of Set 3 | karratha
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | sechura
# Processing Record 10 of Set 3 | deputatskiy
# Processing Record 11 of Set 3 | filingue
# Processing Record 12 of Set 3 | burica
# City not found. Skipping...
# Processing Record 13 of Set 3 | chumikan
# Processing Record 14 of Set 3 | seybaplaya
# Processing Record 15 of Set 3 | kongolo
# Processing Record 16 of Set 3 | tautira
# Processing Record 17 of Set 3 | redding
# Processing Record 18 of Set 3 | oxford
# Processing Record 19 of Set 3 | honiara
# Processing Record 20 of Set 3 | hazorasp
# Processing Record 21 of Set 3 | grindavik
# Processing Record 22 of Set 3 | roma
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | calama
# Processing Record 25 of Set 3 | san juan
# Processing Record 26 of Set 3 | uppsala
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | jalu
# Processing Record 29 of Set 3 | nago
# Processing Record 30 of Set 3 | georgiyevskoye
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | marsa matruh
# Processing Record 33 of Set 3 | urucara
# Processing Record 34 of Set 3 | tiznit
# Processing Record 35 of Set 3 | nata
# Processing Record 36 of Set 3 | morro bay
# Processing Record 37 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 3 | karla
# Processing Record 39 of Set 3 | cap malheureux
# Processing Record 40 of Set 3 | dunedin
# Processing Record 41 of Set 3 | pozega
# Processing Record 42 of Set 3 | leshukonskoye
# Processing Record 43 of Set 3 | camacha
# Processing Record 44 of Set 3 | canico
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | waipawa
# Processing Record 48 of Set 3 | morrope
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | alvdal
# Processing Record 1 of Set 4 | mezen
# Processing Record 2 of Set 4 | isangel
# Processing Record 3 of Set 4 | ostrovnoy
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | paamiut
# Processing Record 6 of Set 4 | egvekinot
# Processing Record 7 of Set 4 | najran
# Processing Record 8 of Set 4 | champerico
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | buala
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | ustye
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | coihaique
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | boshnyakovo
# Processing Record 18 of Set 4 | airai
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | sulangan
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | guaymas
# Processing Record 23 of Set 4 | somerset
# Processing Record 24 of Set 4 | taksimo
# Processing Record 25 of Set 4 | thunder bay
# Processing Record 26 of Set 4 | mwene-ditu
# Processing Record 27 of Set 4 | lebyazhye
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | sorland
# Processing Record 30 of Set 4 | mount isa
# Processing Record 31 of Set 4 | yulin
# Processing Record 32 of Set 4 | magadan
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | waw
# Processing Record 36 of Set 4 | dengzhou
# Processing Record 37 of Set 4 | giovinazzo
# Processing Record 38 of Set 4 | concarneau
# Processing Record 39 of Set 4 | tilichiki
# Processing Record 40 of Set 4 | nelson bay
# Processing Record 41 of Set 4 | chicama
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 4 | teguise
# Processing Record 44 of Set 4 | asau
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | abay
# Processing Record 47 of Set 4 | stephenville
# Processing Record 48 of Set 4 | alexandria
# Processing Record 49 of Set 4 | puertollano
# Processing Record 50 of Set 4 | abu dhabi
# Processing Record 1 of Set 5 | auki
# Processing Record 2 of Set 5 | lasa
# Processing Record 3 of Set 5 | kholtoson
# Processing Record 4 of Set 5 | vestmannaeyjar
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | tigil
# Processing Record 7 of Set 5 | novovasylivka
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | kenai
# Processing Record 10 of Set 5 | lodwar
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | riyadh
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | lompoc
# Processing Record 15 of Set 5 | saint-joseph
# Processing Record 16 of Set 5 | geraldton
# Processing Record 17 of Set 5 | kouroussa
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | brynmawr
# Processing Record 20 of Set 5 | qaqortoq
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | murray bridge
# Processing Record 23 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 5 | talaya
# Processing Record 25 of Set 5 | kloulklubed
# Processing Record 26 of Set 5 | elat
# Processing Record 27 of Set 5 | verkhneuralsk
# Processing Record 28 of Set 5 | bagru
# Processing Record 29 of Set 5 | ambilobe
# Processing Record 30 of Set 5 | salekhard
# Processing Record 31 of Set 5 | coquimbo
# Processing Record 32 of Set 5 | zhigansk
# Processing Record 33 of Set 5 | talara
# Processing Record 34 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 5 | provideniya
# Processing Record 36 of Set 5 | adrar
# Processing Record 37 of Set 5 | bulgan
# Processing Record 38 of Set 5 | bahia blanca
# Processing Record 39 of Set 5 | balikpapan
# Processing Record 40 of Set 5 | hay river
# Processing Record 41 of Set 5 | imbituba
# Processing Record 42 of Set 5 | senno
# Processing Record 43 of Set 5 | la gaulette
# City not found. Skipping...
# Processing Record 44 of Set 5 | ambon
# Processing Record 45 of Set 5 | farias brito
# Processing Record 46 of Set 5 | clovis
# Processing Record 47 of Set 5 | novosergiyevka
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | praia
# Processing Record 50 of Set 5 | zagora
# Processing Record 1 of Set 6 | port elizabeth
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | praia da vitoria
# Processing Record 4 of Set 6 | chapais
# Processing Record 5 of Set 6 | kavaratti
# Processing Record 6 of Set 6 | syracuse
# Processing Record 7 of Set 6 | cockburn town
# Processing Record 8 of Set 6 | ahipara
# Processing Record 9 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | leningradskiy
# Processing Record 11 of Set 6 | constitucion
# Processing Record 12 of Set 6 | currais novos
# Processing Record 13 of Set 6 | iranshahr
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | bahia honda
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | hambantota
# Processing Record 19 of Set 6 | cherskiy
# Processing Record 20 of Set 6 | aktas
# Processing Record 21 of Set 6 | srednekolymsk
# Processing Record 22 of Set 6 | buin
# Processing Record 23 of Set 6 | wodonga
# Processing Record 24 of Set 6 | belaya gora
# Processing Record 25 of Set 6 | tavares
# Processing Record 26 of Set 6 | vestmanna
# Processing Record 27 of Set 6 | lamballe
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | poso
# Processing Record 30 of Set 6 | kalabo
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | vanderhoof
# Processing Record 33 of Set 6 | presidencia roque saenz pena
# Processing Record 34 of Set 6 | orangeburg
# Processing Record 35 of Set 6 | ribeira grande
# Processing Record 36 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | yumen
# Processing Record 38 of Set 6 | smolenka
# Processing Record 39 of Set 6 | buchanan
# Processing Record 40 of Set 6 | castro
# Processing Record 41 of Set 6 | nizwa
# Processing Record 42 of Set 6 | bokino
# Processing Record 43 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | sukhothai
# Processing Record 45 of Set 6 | makakilo city
# Processing Record 46 of Set 6 | redcar
# Processing Record 47 of Set 6 | gat
# Processing Record 48 of Set 6 | helong
# Processing Record 49 of Set 6 | maamba
# Processing Record 50 of Set 6 | naze
# Processing Record 1 of Set 7 | neiafu
# Processing Record 2 of Set 7 | omsukchan
# Processing Record 3 of Set 7 | stykkisholmur
# Processing Record 4 of Set 7 | itaborai
# Processing Record 5 of Set 7 | maposeni
# Processing Record 6 of Set 7 | pori
# Processing Record 7 of Set 7 | aden
# Processing Record 8 of Set 7 | banda aceh
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | katsuura
# Processing Record 11 of Set 7 | vardo
# Processing Record 12 of Set 7 | mount gambier
# Processing Record 13 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 7 | mahibadhoo
# Processing Record 15 of Set 7 | dubbo
# Processing Record 16 of Set 7 | mosquera
# Processing Record 17 of Set 7 | salinopolis
# Processing Record 18 of Set 7 | fairbanks
# Processing Record 19 of Set 7 | huarmey
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | baruun-urt
# Processing Record 22 of Set 7 | pedernales
# Processing Record 23 of Set 7 | veraval
# Processing Record 24 of Set 7 | tigzirt
# Processing Record 25 of Set 7 | oranjemund
# Processing Record 26 of Set 7 | nizhnyaya tavda
# Processing Record 27 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 7 | fort nelson
# Processing Record 31 of Set 7 | zhezkazgan
# Processing Record 32 of Set 7 | pochutla
# Processing Record 33 of Set 7 | espanola
# Processing Record 34 of Set 7 | yeppoon
# Processing Record 35 of Set 7 | oparino
# Processing Record 36 of Set 7 | bathsheba
# Processing Record 37 of Set 7 | los llanos de aridane
# Processing Record 38 of Set 7 | mahon
# Processing Record 39 of Set 7 | maniitsoq
# Processing Record 40 of Set 7 | chiredzi
# Processing Record 41 of Set 7 | porkhov
# Processing Record 42 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 7 | walvis bay
# Processing Record 44 of Set 7 | masallatah
# Processing Record 45 of Set 7 | haines junction
# Processing Record 46 of Set 7 | aklavik
# Processing Record 47 of Set 7 | mapiri
# Processing Record 48 of Set 7 | sinnamary
# Processing Record 49 of Set 7 | la joya
# Processing Record 50 of Set 7 | tasiilaq
# Processing Record 1 of Set 8 | suicheng
# Processing Record 2 of Set 8 | paraiso
# Processing Record 3 of Set 8 | shafranovo
# Processing Record 4 of Set 8 | zhenhai
# Processing Record 5 of Set 8 | mayo
# Processing Record 6 of Set 8 | vernon
# Processing Record 7 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 8 | aykhal
# Processing Record 9 of Set 8 | goias
# Processing Record 10 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 8 | bafq
# Processing Record 12 of Set 8 | mundo nuevo
# Processing Record 13 of Set 8 | shiojiri
# Processing Record 14 of Set 8 | paita
# Processing Record 15 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 8 | eirunepe
# Processing Record 17 of Set 8 | frankfort
# Processing Record 18 of Set 8 | ridgecrest
# Processing Record 19 of Set 8 | posse
# Processing Record 20 of Set 8 | inhambane
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | arraial do cabo
# Processing Record 23 of Set 8 | berdigestyakh
# Processing Record 24 of Set 8 | ayan
# Processing Record 25 of Set 8 | half moon bay
# Processing Record 26 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 27 of Set 8 | lazurne
# Processing Record 28 of Set 8 | zatoka
# Processing Record 29 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 30 of Set 8 | singaraja
# Processing Record 31 of Set 8 | vanimo
# Processing Record 32 of Set 8 | birao
# Processing Record 33 of Set 8 | catalina foothills
# Processing Record 34 of Set 8 | monte alegre
# Processing Record 35 of Set 8 | las vegas
# Processing Record 36 of Set 8 | san quintin
# Processing Record 37 of Set 8 | dunstable
# Processing Record 38 of Set 8 | ravar
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | conde
# Processing Record 41 of Set 8 | tambopata
# Processing Record 42 of Set 8 | bandarbeyla
# Processing Record 43 of Set 8 | parati
# Processing Record 44 of Set 8 | tessalit
# Processing Record 45 of Set 8 | buzmeyin
# Processing Record 46 of Set 8 | abonnema
# Processing Record 47 of Set 8 | ostrovskoye
# Processing Record 48 of Set 8 | berlevag
# Processing Record 49 of Set 8 | san vicente
# Processing Record 50 of Set 8 | cabra
# Processing Record 1 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 2 of Set 9 | macapa
# Processing Record 3 of Set 9 | ozubulu
# Processing Record 4 of Set 9 | ribeira brava
# Processing Record 5 of Set 9 | broome
# Processing Record 6 of Set 9 | bayshore gardens
# Processing Record 7 of Set 9 | slantsy
# Processing Record 8 of Set 9 | zeya
# Processing Record 9 of Set 9 | nyrob
# Processing Record 10 of Set 9 | awbari
# Processing Record 11 of Set 9 | ketchikan
# Processing Record 12 of Set 9 | nagua
# Processing Record 13 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 9 | jacareacanga
# Processing Record 15 of Set 9 | torbay
# Processing Record 16 of Set 9 | zheleznodorozhnyy
# Processing Record 17 of Set 9 | mujiayingzi
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | bowen
# Processing Record 20 of Set 9 | pho chai
# Processing Record 21 of Set 9 | touros
# Processing Record 22 of Set 9 | feldioara
# Processing Record 23 of Set 9 | biak
# Processing Record 24 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | boende
# Processing Record 26 of Set 9 | saiha
# Processing Record 27 of Set 9 | basco
# Processing Record 28 of Set 9 | antalaha
# Processing Record 29 of Set 9 | niles
# Processing Record 30 of Set 9 | ergani
# Processing Record 31 of Set 9 | yatou
# Processing Record 32 of Set 9 | lufilufi
# Processing Record 33 of Set 9 | filadelfia
# Processing Record 34 of Set 9 | sai buri
# Processing Record 35 of Set 9 | elizabeth city
# Processing Record 36 of Set 9 | kurchum
# Processing Record 37 of Set 9 | sapa
# Processing Record 38 of Set 9 | aksum
# Processing Record 39 of Set 9 | wanning
# Processing Record 40 of Set 9 | yagodnoye
# Processing Record 41 of Set 9 | dunda
# Processing Record 42 of Set 9 | dingli
# Processing Record 43 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 9 | chingirlau
# Processing Record 45 of Set 9 | nanyamba
# Processing Record 46 of Set 9 | sam chuk
# Processing Record 47 of Set 9 | sanchazi
# Processing Record 48 of Set 9 | ndjole
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | belmonte
# Processing Record 3 of Set 10 | baykalsk
# Processing Record 4 of Set 10 | tecoanapa
# Processing Record 5 of Set 10 | mandera
# Processing Record 6 of Set 10 | shelburne
# Processing Record 7 of Set 10 | lazaro cardenas
# Processing Record 8 of Set 10 | escanaba
# Processing Record 9 of Set 10 | homa bay
# Processing Record 10 of Set 10 | carauari
# Processing Record 11 of Set 10 | chimbote
# Processing Record 12 of Set 10 | moose jaw
# Processing Record 13 of Set 10 | longhua
# Processing Record 14 of Set 10 | byron bay
# Processing Record 15 of Set 10 | syriam
# Processing Record 16 of Set 10 | kaeo
# Processing Record 17 of Set 10 | santarem
# Processing Record 18 of Set 10 | vegreville
# Processing Record 19 of Set 10 | havoysund
# Processing Record 20 of Set 10 | salento
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | tomatlan
# Processing Record 23 of Set 10 | salalah
# Processing Record 24 of Set 10 | vieques
# Processing Record 25 of Set 10 | broken hill
# Processing Record 26 of Set 10 | severo-yeniseyskiy
# Processing Record 27 of Set 10 | shingu
# Processing Record 28 of Set 10 | comodoro rivadavia
# Processing Record 29 of Set 10 | tuckahoe
# Processing Record 30 of Set 10 | armidale
# Processing Record 31 of Set 10 | gzhatsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | granada
# Processing Record 33 of Set 10 | paredon
# Processing Record 34 of Set 10 | point pedro
# Processing Record 35 of Set 10 | sioux lookout
# Processing Record 36 of Set 10 | passo de camaragibe
# Processing Record 37 of Set 10 | alamos
# Processing Record 38 of Set 10 | louga
# Processing Record 39 of Set 10 | laguna
# Processing Record 40 of Set 10 | ancud
# Processing Record 41 of Set 10 | sao miguel do araguaia
# Processing Record 42 of Set 10 | jasper
# Processing Record 43 of Set 10 | sitka
# Processing Record 44 of Set 10 | boardman
# Processing Record 45 of Set 10 | cochrane
# Processing Record 46 of Set 10 | dustlik
# Processing Record 47 of Set 10 | nikel
# Processing Record 48 of Set 10 | ust-maya
# Processing Record 49 of Set 10 | sola
# Processing Record 50 of Set 10 | novikovo
# Processing Record 1 of Set 11 | esperance
# Processing Record 2 of Set 11 | cayenne
# Processing Record 3 of Set 11 | ronneby
# Processing Record 4 of Set 11 | beringovskiy
# Processing Record 5 of Set 11 | victoria point
# Processing Record 6 of Set 11 | iqaluit
# Processing Record 7 of Set 11 | kungsbacka
# Processing Record 8 of Set 11 | leninskoye
# Processing Record 9 of Set 11 | chara
# Processing Record 10 of Set 11 | yusva
# City not found. Skipping...
# Processing Record 11 of Set 11 | hovd
# Processing Record 12 of Set 11 | dogondoutchi
# Processing Record 13 of Set 11 | monrovia
# Processing Record 14 of Set 11 | hasaki
# Processing Record 15 of Set 11 | lusaka
# Processing Record 16 of Set 11 | oriximina
# Processing Record 17 of Set 11 | kardla
# Processing Record 18 of Set 11 | janauba
# Processing Record 19 of Set 11 | barabinsk
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | oktyabrskoye
# Processing Record 22 of Set 11 | belyy yar
# Processing Record 23 of Set 11 | kendari
# Processing Record 24 of Set 11 | harper
# Processing Record 25 of Set 11 | yermakovskoye
# Processing Record 26 of Set 11 | sao jose da coroa grande
# Processing Record 27 of Set 11 | sananduva
# Processing Record 28 of Set 11 | phuket
# Processing Record 29 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 30 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 11 | prince rupert
# Processing Record 32 of Set 11 | marsh harbour
# Processing Record 33 of Set 11 | santa cruz
# Processing Record 34 of Set 11 | sao gabriel da cachoeira
# Processing Record 35 of Set 11 | hun
# Processing Record 36 of Set 11 | caravelas
# Processing Record 37 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 38 of Set 11 | novi becej
# Processing Record 39 of Set 11 | talnakh
# Processing Record 40 of Set 11 | raton
# Processing Record 41 of Set 11 | ormara
# Processing Record 42 of Set 11 | darhan
# Processing Record 43 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 11 | areosa
# Processing Record 45 of Set 11 | muzhi
# Processing Record 46 of Set 11 | broadstairs
# Processing Record 47 of Set 11 | mumford
# Processing Record 48 of Set 11 | tortoli
# Processing Record 49 of Set 11 | kitui
# Processing Record 50 of Set 11 | talas
# Processing Record 1 of Set 12 | medeiros neto
# Processing Record 2 of Set 12 | port hawkesbury
# Processing Record 3 of Set 12 | inzhavino
# Processing Record 4 of Set 12 | dubno
# Processing Record 5 of Set 12 | bambanglipuro
# Processing Record 6 of Set 12 | maraa
# Processing Record 7 of Set 12 | mackay
# Processing Record 8 of Set 12 | lyuban
# Processing Record 9 of Set 12 | nome
# Processing Record 10 of Set 12 | garh maharaja
# Processing Record 11 of Set 12 | burriana
# Processing Record 12 of Set 12 | kemi
# Processing Record 13 of Set 12 | the valley
# Processing Record 14 of Set 12 | sibolga
# Processing Record 15 of Set 12 | anshun
# Processing Record 16 of Set 12 | van
# Processing Record 17 of Set 12 | teya
# Processing Record 18 of Set 12 | eravur
# Processing Record 19 of Set 12 | baykit
# Processing Record 20 of Set 12 | skelleftea
# Processing Record 21 of Set 12 | doka
# Processing Record 22 of Set 12 | klaksvik
# Processing Record 23 of Set 12 | zabol
# Processing Record 24 of Set 12 | locri
# Processing Record 25 of Set 12 | natal
# Processing Record 26 of Set 12 | sampit
# Processing Record 27 of Set 12 | lensk
# Processing Record 28 of Set 12 | samarai
# Processing Record 29 of Set 12 | mareeba
# Processing Record 30 of Set 12 | horsham
# Processing Record 31 of Set 12 | samfya
# Processing Record 32 of Set 12 | severnoye
# Processing Record 33 of Set 12 | madimba
# Processing Record 34 of Set 12 | gold coast
# Processing Record 35 of Set 12 | kodinsk
# Processing Record 36 of Set 12 | poum
# Processing Record 37 of Set 12 | les cayes
# Processing Record 38 of Set 12 | ostersund
# Processing Record 39 of Set 12 | puerto escondido
# Processing Record 40 of Set 12 | fomboni
# Processing Record 41 of Set 12 | namatanai
# Processing Record 42 of Set 12 | chake chake
# Processing Record 43 of Set 12 | akureyri
# Processing Record 44 of Set 12 | pristina
# Processing Record 45 of Set 12 | turinskaya sloboda
# Processing Record 46 of Set 12 | do gonbadan
# Processing Record 47 of Set 12 | cozumel
# Processing Record 48 of Set 12 | hamilton
# Processing Record 49 of Set 12 | nikolayevsk-na-amure
# Processing Record 50 of Set 12 | shumyachi
# Processing Record 1 of Set 13 | quincy
# Processing Record 2 of Set 13 | kropotkin
# Processing Record 3 of Set 13 | shitanjing
# Processing Record 4 of Set 13 | oksfjord
# Processing Record 5 of Set 13 | usvyaty
# Processing Record 6 of Set 13 | contamana
# Processing Record 7 of Set 13 | vao
# Processing Record 8 of Set 13 | itanhem
# Processing Record 9 of Set 13 | shenjiamen
# Processing Record 10 of Set 13 | warqla
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Lincoln      AU -34.7333  135.8667     57.92        62          77
# 1       Mataura      NZ -46.1927  168.8643     44.47        91          83
# 2     Norrtalje      SE  59.7580   18.7050     51.03        73          36
# 3  Punta Arenas      CL -53.1500  -70.9167     33.12        86          19
# 4     Upernavik      GL  72.7868  -56.1549     19.92        59           0
# 5      Souillac      MU -20.5167   57.5167     76.35        70          17
# 6      Khatanga      RU  71.9667  102.5000     36.97        69          92
# 7         Pisco      PE -13.7000  -76.2167     60.03        86          78
# 8     Ilulissat      GL  69.2167  -51.1000     17.62        62           0
# 9  Saint-Pierre      RE -21.3393   55.4781     80.29        61           0
#
#    Wind Speed Current Description
# 0       12.28       broken clouds
# 1        3.11       broken clouds
# 2        1.63    scattered clouds
# 3       13.20          few clouds
# 4        4.05           clear sky
# 5       17.34          few clouds
# 6       13.11     overcast clouds
# 7        3.02       broken clouds
# 8        9.22           clear sky
# 9       27.63           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
